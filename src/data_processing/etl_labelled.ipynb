# %%
import pandas as pd

import spacy
from scispacy.abbreviation import AbbreviationDetector

from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

import html
import emoji
from googletrans import Translator

from pathlib import Path
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from database import database_manager as dbm
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/raimuu/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# **Extract**

# %%
file_path = "../../data/raw/covid_twitter_labelled.zip"
df = pd.read_csv(file_path, compression='zip')
new_df = df["Processed_Text"].head()
new_df.to_csv("testing")
display(df)
# Out:
#         Unnamed: 0  index                                               text  \
# 0                0      0  RT @danpfeiffer: Isn't wild that the President...
# 1                1      2  RT @Complex: 90-year-old woman dies from Coron...
# 2                2      4  RT @jennycohn1: We need their help not so much...
# 3                3      6  RT @AmbJehangir: Deadly but still funny (?)\nE...
# 4                4      8  RT @SethAbramson: BREAKING NEWS: Daily Coronav...
# ...            ...    ...                                                ...
# 119967       41954  89181  RT @kairyssdal: This is...\n3. An economic cri...
# 119968       41955  89182  After watching Billions, i basically learned t...
# 119969       41956  89185  All Plymouth schools to be closed for cleaning...
# 119970       41957  89191  RT @PaulDoroshenko: Can you sue the president ...
# 119971       41958  89193  RT @TheeGreatJA: Had to check on you. They say...
#
#                                   date truncated  \
# 0       Thu Apr 02 00:27:49 +0000 2020     FALSE
# 1       Thu Apr 02 00:27:51 +0000 2020     FALSE
# 2       Thu Apr 02 00:27:52 +0000 2020     FALSE
# 3       Thu Apr 02 00:27:58 +0000 2020     FALSE
# 4       Thu Apr 02 00:28:24 +0000 2020     FALSE
# ...                                ...       ...
# 119967  Fri Mar 06 00:04:20 +0000 2020     FALSE
# 119968  Fri Mar 06 00:04:20 +0000 2020     FALSE
# 119969  Fri Mar 06 00:04:21 +0000 2020     FALSE
# 119970  Fri Mar 06 00:04:22 +0000 2020     FALSE
# 119971  Fri Mar 06 00:04:22 +0000 2020     FALSE
#
#                                            Processed_Text  sentiment  \
# 0       danpfeiff isnt wild presid unit state own thou...          3
# 1       complex 90yearold woman die coronavirus ask do...          3
# 2       jennycohn1 need help much discuss happen 2016 ...          3
# 3       ambjehangir dead still funni even dead contagi...          1
# 4       sethabramson break news daili coronavirus deat...          3
# ...                                                   ...        ...
# 119967                            kairyssd 3 econom crisi          2
# 119968  watch billion basic learn make stock market mo...          3
# 119969  plymouth school close clean friday student tes...          3
# 119970          pauldoroshenko sue presid bad medic advic          0
# 119971  theegreatja check say lil coronavirus citi cra...          0
#
#         new_sentiment
# 0                   3
# 1                   3
# 2                   3
# 3                   1
# 4                   3
# ...               ...
# 119967              1
# 119968              3
# 119969              3
# 119970              0
# 119971              0
#
# [119972 rows x 8 columns]

# %% [markdown]
# **Transform**

# %%
# remove unwanted columns
columns_to_drop = ["text", "Unnamed: 0", "index", "truncated", "new_sentiment"]
columns_to_rename = {"Processed_Text": "text", "sentiment": "numeric_labelled_sentiment"}
df = df.drop(columns=columns_to_drop).reset_index(drop=True)
df = df.rename(columns=columns_to_rename)
display(df)
# Out:
#                                   date  \
# 0       Thu Apr 02 00:27:49 +0000 2020
# 1       Thu Apr 02 00:27:51 +0000 2020
# 2       Thu Apr 02 00:27:52 +0000 2020
# 3       Thu Apr 02 00:27:58 +0000 2020
# 4       Thu Apr 02 00:28:24 +0000 2020
# ...                                ...
# 119967  Fri Mar 06 00:04:20 +0000 2020
# 119968  Fri Mar 06 00:04:20 +0000 2020
# 119969  Fri Mar 06 00:04:21 +0000 2020
# 119970  Fri Mar 06 00:04:22 +0000 2020
# 119971  Fri Mar 06 00:04:22 +0000 2020
#
#                                                      text  \
# 0       danpfeiff isnt wild presid unit state own thou...
# 1       complex 90yearold woman die coronavirus ask do...
# 2       jennycohn1 need help much discuss happen 2016 ...
# 3       ambjehangir dead still funni even dead contagi...
# 4       sethabramson break news daili coronavirus deat...
# ...                                                   ...
# 119967                            kairyssd 3 econom crisi
# 119968  watch billion basic learn make stock market mo...
# 119969  plymouth school close clean friday student tes...
# 119970          pauldoroshenko sue presid bad medic advic
# 119971  theegreatja check say lil coronavirus citi cra...
#
#         numeric_labelled_sentiment
# 0                                3
# 1                                3
# 2                                3
# 3                                1
# 4                                3
# ...                            ...
# 119967                           2
# 119968                           3
# 119969                           3
# 119970                           0
# 119971                           0
#
# [119972 rows x 3 columns]

# %%
def unescape_html(text): 
    return html.unescape(text)

df_clean = df.dropna().copy() # drop all rows containing null

df_clean['text'] = (
    df_clean['text']
    .str.replace(r'http\S+|www.\S+', '', regex=True) # remove links
    .str.replace(r'[\n\t]', ' ', regex=True) # remove \t\n
    .apply(unescape_html) # escape html formatting
    .apply(emoji.demojize) # replace emojis with their symbolic name
    .str.replace(r'[^\w\s.,!?;:\-()\'"/&]', '', regex=True) # remove non-alphanumeric characters (symbols not in this set)
    .str.replace(":", " ")
    .str.replace("_", " ")
)

# convert columns to appropriate data types
df_clean = df_clean.drop_duplicates(subset='text') # remove duplicates after cleaning/unifying format
df_clean = df_clean.reset_index(drop=True)

# %%
# convert numeric_labelled_sentiment to labeleld_sentiment
def normalize_sent(numeric_sent):
    if int(numeric_sent) > 2:
        return "positive"
    elif int(numeric_sent) < 2:
        return "negative"
    else:
        return "neutral"

df_clean['labelled_sentiment'] = df_clean['numeric_labelled_sentiment'].apply(normalize_sent)

# %% [markdown]
# **Load**

# %%
# %%script true
# newTable = "processed_labelled_twitter_data"
# dbm.create_table(table_name=newTable, dataframe=df_clean, replace=True)
#
# query = f"""
#     SELECT * FROM "{newTable}"
# """
# df = dbm.query_db(query)
# display(df)
# Out:
# The table 'processed_labelled_twitter_data' already exists. Replacing entries.
#           id                            date  \
# 0          0  Thu Apr 02 00:27:49 +0000 2020
# 1          1  Thu Apr 02 00:27:51 +0000 2020
# 2          2  Thu Apr 02 00:27:52 +0000 2020
# 3          3  Thu Apr 02 00:27:58 +0000 2020
# 4          4  Thu Apr 02 00:28:24 +0000 2020
# ...      ...                             ...
# 64942  64942  Fri Mar 06 00:04:19 +0000 2020
# 64943  64943  Fri Mar 06 00:04:20 +0000 2020
# 64944  64944  Fri Mar 06 00:04:20 +0000 2020
# 64945  64945  Fri Mar 06 00:04:21 +0000 2020
# 64946  64946  Fri Mar 06 00:04:22 +0000 2020
#
#                                                     text  \
# 0      danpfeiff isnt wild presid unit state own thou...
# 1      complex 90yearold woman die coronavirus ask do...
# 2      jennycohn1 need help much discuss happen 2016 ...
# 3      ambjehangir dead still funni even dead contagi...
# 4      sethabramson break news daili coronavirus deat...
# ...                                                  ...
# 64942  rtcom moscow declar high alert coronavirus thr...
# 64943                            kairyssd 3 econom crisi
# 64944  watch billion basic learn make stock market mo...
# 64945  plymouth school close clean friday student tes...
# 64946          pauldoroshenko sue presid bad medic advic
#
#        numeric_labelled_sentiment labelled_sentiment
# 0                               3           positive
# 1                               3           positive
# 2                               3           positive
# 3                               1           negative
# 4                               3           positive
# ...                           ...                ...
# 64942                           3           positive
# 64943                           2            neutral
# 64944                           3           positive
# 64945                           3           positive
# 64946                           0           negative
#
# [64947 rows x 5 columns]
